# %% [markdown]
# # Filter Data

# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
df_FANG = pd.read_csv('data/FANG.csv', encoding="ISO-8859-1", index_col=[0])
df_FANG_dates = pd.read_excel("data/dates/Document_Filing_Dates.xlsx", sheet_name='FANG')
df_FANG.drop(['company', 'open', 'high', 'low','adjusted_close', 'volume', 'dividend_amount', 'split_coefficient' ,'crude_price'], axis=1, inplace=True)
df_FANG['date'] = pd.to_datetime(df_FANG['date'])
df_FANG = df_FANG.set_index('date')
df_FANG = df_FANG.resample('D').mean()
df_FANG = df_FANG.fillna(method='ffill')
df_FANG = df_FANG.reset_index(drop=False)
df_FANG_dates.rename(columns = {'Filing Date':'date'}, inplace = True)
df_FANG_dates['1_Day'] = df_FANG_dates['date'] + np.timedelta64(1,'D')
df_FANG_dates['1_Month'] = df_FANG_dates['date'] + np.timedelta64(30,'D')
df_FANG_dates['3_Month'] = df_FANG_dates['date'] + np.timedelta64(90,'D')
df_FANG_dates = pd.merge(df_FANG_dates, df_FANG, on='date' ,how='left')
df_FANG.rename(columns = {'date':'1_Day'}, inplace = True)
df_FANG.rename(columns = {'close':'close_1_Day'}, inplace = True)
df_FANG_dates = pd.merge(df_FANG_dates, df_FANG, on='1_Day' ,how='left')
df_FANG.rename(columns = {'1_Day':'1_Month'}, inplace = True)
df_FANG.rename(columns = {'close_1_Day':'close_1_Month'}, inplace = True)
df_FANG_dates = pd.merge(df_FANG_dates, df_FANG, on='1_Month' ,how='left')
df_FANG.rename(columns = {'1_Month':'3_Month'}, inplace = True)
df_FANG.rename(columns = {'close_1_Month':'close_3_Month'}, inplace = True)
df_FANG_dates = pd.merge(df_FANG_dates, df_FANG, on='3_Month' ,how='left')
df_FANG_dates['Name'] = 'FANG'

# %%
df_FANG_dates
# Out:
#    Filings       date      1_Day    1_Month    3_Month   close  close_1_Day  \
# 0     10-K 2014-02-19 2014-02-20 2014-03-21 2014-05-20   61.04        62.67
# 1     10-Q 2014-05-09 2014-05-10 2014-06-08 2014-08-07   71.24        71.24
# 2   10-Q/A 2014-05-28 2014-05-29 2014-06-27 2014-08-26   71.39        75.02
# 3     10-Q 2014-08-07 2014-08-08 2014-09-06 2014-11-05   76.58        77.45
# 4     10-Q 2014-11-06 2014-11-07 2014-12-06 2015-02-04   65.82        69.49
# 5     10-K 2015-02-20 2015-02-21 2015-03-22 2015-05-21   75.09        75.09
# 6     10-Q 2015-05-07 2015-05-08 2015-06-06 2015-08-05   75.34        77.01
# 7     10-Q 2015-08-10 2015-08-11 2015-09-09 2015-11-08   70.19        70.87
# 8     10-Q 2015-11-06 2015-11-07 2015-12-06 2016-02-04   77.79        77.79
# 9   10-Q/A 2015-11-17 2015-11-18 2015-12-17 2016-02-15   79.61        81.42
# 10    10-K 2016-02-19 2016-02-20 2016-03-20 2016-05-19   72.08        72.08
# ...

# %%
df_MDU_dates = pd.read_excel("data/dates/Document_Filing_Dates.xlsx", sheet_name='MDU')
df_MDU = pd.read_csv('data/MDU.csv', encoding="ISO-8859-1", index_col=[0])
df_MDU.drop(['company', 'open', 'high', 'low','adjusted_close', 'volume', 'dividend_amount', 'split_coefficient' ,'crude_price'], axis=1, inplace=True)
df_MDU['date'] = pd.to_datetime(df_MDU['date'])
df_MDU = df_MDU.set_index('date')
df_MDU = df_MDU.resample('D').mean()
df_MDU = df_MDU.fillna(method='ffill')
df_MDU = df_MDU.reset_index(drop=False)
df_MDU_dates.rename(columns = {'Filing Date':'date'}, inplace = True)
df_MDU_dates['1_Day'] = df_MDU_dates['date'] + np.timedelta64(1,'D')
df_MDU_dates['1_Month'] = df_MDU_dates['date'] + np.timedelta64(30,'D')
df_MDU_dates['3_Month'] = df_MDU_dates['date'] + np.timedelta64(90,'D')
df_MDU_dates = pd.merge(df_MDU_dates, df_MDU, on='date' ,how='left')
df_MDU.rename(columns = {'date':'1_Day'}, inplace = True)
df_MDU.rename(columns = {'close':'close_1_Day'}, inplace = True)
df_MDU_dates = pd.merge(df_MDU_dates, df_MDU, on='1_Day' ,how='left')
df_MDU.rename(columns = {'1_Day':'1_Month'}, inplace = True)
df_MDU.rename(columns = {'close_1_Day':'close_1_Month'}, inplace = True)
df_MDU_dates = pd.merge(df_MDU_dates, df_MDU, on='1_Month' ,how='left')
df_MDU.rename(columns = {'1_Month':'3_Month'}, inplace = True)
df_MDU.rename(columns = {'close_1_Month':'close_3_Month'}, inplace = True)
df_MDU_dates = pd.merge(df_MDU_dates, df_MDU, on='3_Month' ,how='left')
df_MDU_dates['Name'] = 'MDU'

# %%
df_MDU_dates
# Out:
#    Filings       date      1_Day    1_Month    3_Month  close  close_1_Day  \
# 0     10-K 2014-02-21 2014-02-22 2014-03-23 2014-05-22  34.55        34.55
# 1     10-Q 2014-05-07 2014-05-08 2014-06-06 2014-08-05  35.77        35.07
# 2     10-Q 2014-08-08 2014-08-09 2014-09-07 2014-11-06  30.53        30.53
# 3     10-Q 2014-11-07 2014-11-08 2014-12-07 2015-02-05  26.36        26.36
# 4     10-K 2015-02-20 2015-02-21 2015-03-22 2015-05-21  23.02        23.02
# 5     10-Q 2015-05-08 2015-05-09 2015-06-07 2015-08-06  20.48        20.48
# 6     10-Q 2015-08-04 2015-08-05 2015-09-03 2015-11-02  17.38        17.55
# 7     10-Q 2015-11-06 2015-11-07 2015-12-06 2016-02-04  18.48        18.48
# 8     10-K 2016-02-19 2016-02-20 2016-03-20 2016-05-19  17.40        17.40
# 9     10-Q 2016-05-06 2016-05-07 2016-06-05 2016-08-04  20.90        20.90
# 10    10-Q 2016-08-05 2016-08-06 2016-09-04 2016-11-03  23.66        23.66
# ...

# %%
df_PE_dates = pd.read_excel("data/dates/Document_Filing_Dates.xlsx", sheet_name='PE')
df_PE = pd.read_csv('data/PE.csv', encoding="ISO-8859-1", index_col=[0])
df_PE.drop(['company' ,'open', 'high', 'low','adjusted_close', 'volume', 'dividend_amount', 'split_coefficient' ,'crude_price'], axis=1, inplace=True)
df_PE_dates.drop(['**they started mid 2014'], axis=1, inplace=True)


df_PE['date'] = pd.to_datetime(df_PE['date'])
df_PE = df_PE.set_index('date')
df_PE = df_PE.resample('D').mean()
df_PE = df_PE.fillna(method='ffill')
df_PE = df_PE.reset_index(drop=False)
df_PE_dates.rename(columns = {'Filing Date':'date'}, inplace = True)
df_PE_dates['1_Day'] = df_PE_dates['date'] + np.timedelta64(1,'D')
df_PE_dates['1_Month'] = df_PE_dates['date'] + np.timedelta64(30,'D')
df_PE_dates['3_Month'] = df_PE_dates['date'] + np.timedelta64(90,'D')
df_PE_dates = pd.merge(df_PE_dates, df_PE, on='date' ,how='left')
df_PE.rename(columns = {'date':'1_Day'}, inplace = True)
df_PE.rename(columns = {'close':'close_1_Day'}, inplace = True)
df_PE_dates = pd.merge(df_PE_dates, df_PE, on='1_Day' ,how='left')
df_PE.rename(columns = {'1_Day':'1_Month'}, inplace = True)
df_PE.rename(columns = {'close_1_Day':'close_1_Month'}, inplace = True)
df_PE_dates = pd.merge(df_PE_dates, df_PE, on='1_Month' ,how='left')
df_PE.rename(columns = {'1_Month':'3_Month'}, inplace = True)
df_PE.rename(columns = {'close_1_Month':'close_3_Month'}, inplace = True)
df_PE_dates = pd.merge(df_PE_dates, df_PE, on='3_Month' ,how='left')
df_PE_dates['Name'] = 'PE'

df_PE_dates.drop(df_PE_dates.columns[df_PE_dates.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %%
df_PE_dates
# Out:
#    Filings       date      1_Day    1_Month    3_Month  close  close_1_Day  \
# 0     10-Q 2014-08-14 2014-08-15 2014-09-13 2014-11-12  19.89        20.43
# 1     10-Q 2014-11-14 2014-11-15 2014-12-14 2015-02-12  17.95        17.95
# 2     10-K 2015-03-11 2015-03-12 2015-04-10 2015-06-09  14.33        14.57
# 3     10-Q 2015-05-14 2015-05-15 2015-06-13 2015-08-12  17.30        17.62
# 4     10-Q 2015-08-13 2015-08-14 2015-09-12 2015-11-11  15.90        16.16
# 5     10-Q 2015-11-06 2015-11-07 2015-12-06 2016-02-04  18.13        18.13
# 6     10-K 2016-02-29 2016-03-01 2016-03-30 2016-05-29  18.38        18.93
# 7     10-Q 2016-05-06 2016-05-07 2016-06-05 2016-08-04  23.81        23.81
# 8     10-Q 2016-08-05 2016-08-06 2016-09-04 2016-11-03  32.50        32.50
# 9     10-Q 2016-11-04 2016-11-05 2016-12-04 2017-02-02  33.17        33.17
# 10    10-K 2017-02-27 2017-02-28 2017-03-29 2017-05-28  30.77        30.39
# ...

# %%
df_MRO_dates = pd.read_excel("data/dates/Document_Filing_Dates.xlsx", sheet_name='MRO')
df_MRO = pd.read_csv('data/MRO.csv', encoding="ISO-8859-1", index_col=[0])
df_MRO.drop(['company', 'open', 'high', 'low','adjusted_close', 'volume', 'dividend_amount', 'split_coefficient' ,'crude_price'], axis=1, inplace=True)
df_MRO['date'] = pd.to_datetime(df_MRO['date'])
df_MRO = df_MRO.set_index('date')
df_MRO = df_MRO.resample('D').mean()
df_MRO = df_MRO.fillna(method='ffill')
df_MRO = df_MRO.reset_index(drop=False)
df_MRO_dates.rename(columns = {'Filing Date':'date'}, inplace = True)
df_MRO_dates['1_Day'] = df_MRO_dates['date'] + np.timedelta64(1,'D')
df_MRO_dates['1_Month'] = df_MRO_dates['date'] + np.timedelta64(30,'D')
df_MRO_dates['3_Month'] = df_MRO_dates['date'] + np.timedelta64(90,'D')
df_MRO_dates = pd.merge(df_MRO_dates, df_MRO, on='date' ,how='left')
df_MRO.rename(columns = {'date':'1_Day'}, inplace = True)
df_MRO.rename(columns = {'close':'close_1_Day'}, inplace = True)
df_MRO_dates = pd.merge(df_MRO_dates, df_MRO, on='1_Day' ,how='left')
df_MRO.rename(columns = {'1_Day':'1_Month'}, inplace = True)
df_MRO.rename(columns = {'close_1_Day':'close_1_Month'}, inplace = True)
df_MRO_dates = pd.merge(df_MRO_dates, df_MRO, on='1_Month' ,how='left')
df_MRO.rename(columns = {'1_Month':'3_Month'}, inplace = True)
df_MRO.rename(columns = {'close_1_Month':'close_3_Month'}, inplace = True)
df_MRO_dates = pd.merge(df_MRO_dates, df_MRO, on='3_Month' ,how='left')
df_MRO_dates['Name'] = 'MRO'

# %%
df_MRO_dates
# Out:
#    Filings       date      1_Day    1_Month    3_Month  close  close_1_Day  \
# 0     10-K 2014-02-28 2014-03-01 2014-03-30 2014-05-29  33.50        33.50
# 1     10-Q 2014-05-07 2014-05-08 2014-06-06 2014-08-05  35.52        35.70
# 2     10-Q 2014-08-05 2014-08-06 2014-09-04 2014-11-03  38.46        38.93
# 3   10-Q/A 2014-08-07 2014-08-08 2014-09-06 2014-11-05  38.09        39.08
# 4     10-Q 2014-11-04 2014-11-05 2014-12-04 2015-02-02  33.36        33.57
# 5     10-K 2015-03-02 2015-03-03 2015-04-01 2015-05-31  27.67        27.74
# 6     10-Q 2015-05-07 2015-05-08 2015-06-06 2015-08-05  28.92        29.31
# 7     10-Q 2015-08-06 2015-08-07 2015-09-05 2015-11-04  19.45        18.40
# 8     10-Q 2015-11-05 2015-11-06 2015-12-05 2016-02-03  19.00        18.29
# 9     10-K 2016-02-25 2016-02-26 2016-03-26 2016-05-25   7.39         8.03
# 10    10-Q 2016-05-05 2016-05-06 2016-06-04 2016-08-03  12.07        12.03
# ...

# %%
df_LPI_dates = pd.read_excel("data/dates/Document_Filing_Dates.xlsx", sheet_name='LPI')
df_LPI = pd.read_csv('data/LPI.csv', encoding="ISO-8859-1", index_col=[0])
df_LPI.drop(['company', 'open', 'high', 'low','adjusted_close', 'volume', 'dividend_amount', 'split_coefficient' ,'crude_price'], axis=1, inplace=True)
df_LPI['date'] = pd.to_datetime(df_LPI['date'])
df_LPI = df_LPI.set_index('date')
df_LPI = df_LPI.resample('D').mean()
df_LPI = df_LPI.fillna(method='ffill')
df_LPI = df_LPI.reset_index(drop=False)
df_LPI_dates.rename(columns = {'Filing Date':'date'}, inplace = True)
df_LPI_dates['1_Day'] = df_LPI_dates['date'] + np.timedelta64(1,'D')
df_LPI_dates['1_Month'] = df_LPI_dates['date'] + np.timedelta64(30,'D')
df_LPI_dates['3_Month'] = df_LPI_dates['date'] + np.timedelta64(90,'D')
df_LPI_dates = pd.merge(df_LPI_dates, df_LPI, on='date' ,how='left')
df_LPI.rename(columns = {'date':'1_Day'}, inplace = True)
df_LPI.rename(columns = {'close':'close_1_Day'}, inplace = True)
df_LPI_dates = pd.merge(df_LPI_dates, df_LPI, on='1_Day' ,how='left')
df_LPI.rename(columns = {'1_Day':'1_Month'}, inplace = True)
df_LPI.rename(columns = {'close_1_Day':'close_1_Month'}, inplace = True)
df_LPI_dates = pd.merge(df_LPI_dates, df_LPI, on='1_Month' ,how='left')
df_LPI.rename(columns = {'1_Month':'3_Month'}, inplace = True)
df_LPI.rename(columns = {'close_1_Month':'close_3_Month'}, inplace = True)
df_LPI_dates = pd.merge(df_LPI_dates, df_LPI, on='3_Month' ,how='left')
df_LPI_dates['Name'] = 'LPI'

# %%
df_LPI_dates
# Out:
#    Filings       date      1_Day    1_Month    3_Month  close  close_1_Day  \
# 0     10-K 2014-02-27 2014-02-28 2014-03-29 2014-05-28  25.60        26.09
# 1     10-Q 2014-05-08 2014-05-09 2014-06-07 2014-08-06  28.40        28.28
# 2     10-Q 2014-08-07 2014-08-08 2014-09-06 2014-11-05  24.11        24.52
# 3     10-Q 2014-11-06 2014-11-07 2014-12-06 2015-02-04  18.03        19.08
# 4     10-K 2015-02-26 2015-02-27 2015-03-28 2015-05-27  12.26        11.93
# 5     10-Q 2015-05-07 2015-05-08 2015-06-06 2015-08-05  13.72        13.34
# 6     10-Q 2015-08-06 2015-08-07 2015-09-05 2015-11-04   8.51         8.01
# 7     10-Q 2015-11-05 2015-11-06 2015-12-05 2016-02-03  12.32        12.05
# 8     10-K 2016-02-17 2016-02-18 2016-03-18 2016-05-17   5.07         4.74
# 9     10-Q 2016-05-05 2016-05-06 2016-06-04 2016-08-03  12.60        11.94
# 10    10-Q 2016-08-04 2016-08-05 2016-09-03 2016-11-02  10.96        11.27
# ...

# %%
df_GPOR_dates = pd.read_excel("data/dates/Document_Filing_Dates.xlsx", sheet_name='GPOR')
df_GPOR = pd.read_csv('data/GPOR.csv', encoding="ISO-8859-1", index_col=[0])
df_GPOR.drop(['company', 'open', 'high', 'low','adjusted_close', 'volume', 'dividend_amount', 'split_coefficient' ,'crude_price'], axis=1, inplace=True)
df_GPOR['date'] = pd.to_datetime(df_GPOR['date'])
df_GPOR = df_GPOR.set_index('date')
df_GPOR = df_GPOR.resample('D').mean()
df_GPOR = df_GPOR.fillna(method='ffill')
df_GPOR = df_GPOR.reset_index(drop=False)
df_GPOR_dates.rename(columns = {'Filing Date':'date'}, inplace = True)
df_GPOR_dates['1_Day'] = df_GPOR_dates['date'] + np.timedelta64(1,'D')
df_GPOR_dates['1_Month'] = df_GPOR_dates['date'] + np.timedelta64(30,'D')
df_GPOR_dates['3_Month'] = df_GPOR_dates['date'] + np.timedelta64(90,'D')
df_GPOR_dates = pd.merge(df_GPOR_dates, df_GPOR, on='date' ,how='left')
df_GPOR.rename(columns = {'date':'1_Day'}, inplace = True)
df_GPOR.rename(columns = {'close':'close_1_Day'}, inplace = True)
df_GPOR_dates = pd.merge(df_GPOR_dates, df_GPOR, on='1_Day' ,how='left')
df_GPOR.rename(columns = {'1_Day':'1_Month'}, inplace = True)
df_GPOR.rename(columns = {'close_1_Day':'close_1_Month'}, inplace = True)
df_GPOR_dates = pd.merge(df_GPOR_dates, df_GPOR, on='1_Month' ,how='left')
df_GPOR.rename(columns = {'1_Month':'3_Month'}, inplace = True)
df_GPOR.rename(columns = {'close_1_Month':'close_3_Month'}, inplace = True)
df_GPOR_dates = pd.merge(df_GPOR_dates, df_GPOR, on='3_Month' ,how='left')
df_GPOR_dates['Name'] = 'GPOR'

# %%
df_GPOR_dates
# Out:
#    Filings       date      1_Day    1_Month    3_Month  close  close_1_Day  \
# 0     10-K 2014-02-28 2014-03-01 2014-03-30 2014-05-29  66.15        66.15
# 1     10-Q 2014-05-09 2014-05-10 2014-06-08 2014-08-07  60.88        60.88
# 2     10-Q 2014-08-07 2014-08-08 2014-09-06 2014-11-05  54.78        55.74
# 3     10-Q 2014-11-07 2014-11-08 2014-12-07 2015-02-05  55.16        55.16
# 4     10-K 2015-02-27 2015-02-28 2015-03-29 2015-05-28  45.81        45.81
# 5     10-Q 2015-05-07 2015-05-08 2015-06-06 2015-08-05  44.72        45.85
# 6     10-Q 2015-08-07 2015-08-08 2015-09-06 2015-11-05  33.16        33.16
# 7     10-Q 2015-11-05 2015-11-06 2015-12-05 2016-02-03  30.49        30.33
# 8     10-K 2016-02-19 2016-02-20 2016-03-20 2016-05-19  27.16        27.16
# 9     10-Q 2016-05-05 2016-05-06 2016-06-04 2016-08-03  27.92        28.68
# 10    10-Q 2016-08-05 2016-08-06 2016-09-04 2016-11-03  26.21        26.21
# ...

# %%
df_RRC_dates = pd.read_excel("data/dates/Document_Filing_Dates.xlsx", sheet_name='RRC')
df_RRC = pd.read_csv('data/RRC.csv', encoding="ISO-8859-1", index_col=[0])
df_RRC.drop(['company', 'open', 'high', 'low','adjusted_close', 'volume', 'dividend_amount', 'split_coefficient' ,'crude_price'], axis=1, inplace=True)
df_RRC['date'] = pd.to_datetime(df_RRC['date'])
df_RRC = df_RRC.set_index('date')
df_RRC = df_RRC.resample('D').mean()
df_RRC = df_RRC.fillna(method='ffill')
df_RRC = df_RRC.reset_index(drop=False)
df_RRC_dates.rename(columns = {'Filing Date':'date'}, inplace = True)
df_RRC_dates['1_Day'] = df_RRC_dates['date'] + np.timedelta64(1,'D')
df_RRC_dates['1_Month'] = df_RRC_dates['date'] + np.timedelta64(30,'D')
df_RRC_dates['3_Month'] = df_RRC_dates['date'] + np.timedelta64(90,'D')
df_RRC_dates = pd.merge(df_RRC_dates, df_RRC, on='date' ,how='left')
df_RRC.rename(columns = {'date':'1_Day'}, inplace = True)
df_RRC.rename(columns = {'close':'close_1_Day'}, inplace = True)
df_RRC_dates = pd.merge(df_RRC_dates, df_RRC, on='1_Day' ,how='left')
df_RRC.rename(columns = {'1_Day':'1_Month'}, inplace = True)
df_RRC.rename(columns = {'close_1_Day':'close_1_Month'}, inplace = True)
df_RRC_dates = pd.merge(df_RRC_dates, df_RRC, on='1_Month' ,how='left')
df_RRC.rename(columns = {'1_Month':'3_Month'}, inplace = True)
df_RRC.rename(columns = {'close_1_Month':'close_3_Month'}, inplace = True)
df_RRC_dates = pd.merge(df_RRC_dates, df_RRC, on='3_Month' ,how='left')
df_RRC_dates['Name'] = 'RRC'

# %%
df_RRC_dates
# Out:
#    Filings       date      1_Day    1_Month    3_Month  close  close_1_Day  \
# 0     10-K 2014-02-26 2014-02-27 2014-03-28 2014-05-27  84.94        86.76
# 1     10-Q 2014-04-28 2014-04-29 2014-05-28 2014-07-27  91.48        90.43
# 2   10-K/A 2014-06-23 2014-06-24 2014-07-23 2014-09-21  88.02        85.67
# 3     10-Q 2014-07-28 2014-07-29 2014-08-27 2014-10-26  76.27        78.15
# 4     10-Q 2014-10-29 2014-10-30 2014-11-28 2015-01-27  66.90        66.06
# 5     10-K 2015-02-24 2015-02-25 2015-03-26 2015-05-25  51.24        53.91
# 6     10-Q 2015-04-28 2015-04-29 2015-05-28 2015-07-27  62.30        62.06
# 7     10-Q 2015-07-28 2015-07-29 2015-08-27 2015-10-26  43.95        42.64
# 8     10-Q 2015-10-28 2015-10-29 2015-11-27 2016-01-26  28.83        29.64
# 9     10-K 2016-02-25 2016-02-26 2016-03-26 2016-05-25  23.35        23.89
# 10    10-Q 2016-04-28 2016-04-29 2016-05-28 2016-07-27  40.75        44.11
# ...

# %%
df_EQT_dates = pd.read_excel("data/dates/Document_Filing_Dates.xlsx", sheet_name='EQT')
df_EQT = pd.read_csv('data/EQT.csv', encoding="ISO-8859-1", index_col=[0])
df_EQT.drop(['company', 'open', 'high', 'low','adjusted_close', 'volume', 'dividend_amount', 'split_coefficient' ,'crude_price'], axis=1, inplace=True)
df_EQT['date'] = pd.to_datetime(df_EQT['date'])
df_EQT = df_EQT.set_index('date')
df_EQT = df_EQT.resample('D').mean()
df_EQT = df_EQT.fillna(method='ffill')
df_EQT = df_EQT.reset_index(drop=False)
df_EQT_dates.rename(columns = {'Filing Date':'date'}, inplace = True)
df_EQT_dates['1_Day'] = df_EQT_dates['date'] + np.timedelta64(1,'D')
df_EQT_dates['1_Month'] = df_EQT_dates['date'] + np.timedelta64(30,'D')
df_EQT_dates['3_Month'] = df_EQT_dates['date'] + np.timedelta64(90,'D')
df_EQT_dates = pd.merge(df_EQT_dates, df_EQT, on='date' ,how='left')
df_EQT.rename(columns = {'date':'1_Day'}, inplace = True)
df_EQT.rename(columns = {'close':'close_1_Day'}, inplace = True)
df_EQT_dates = pd.merge(df_EQT_dates, df_EQT, on='1_Day' ,how='left')
df_EQT.rename(columns = {'1_Day':'1_Month'}, inplace = True)
df_EQT.rename(columns = {'close_1_Day':'close_1_Month'}, inplace = True)
df_EQT_dates = pd.merge(df_EQT_dates, df_EQT, on='1_Month' ,how='left')
df_EQT.rename(columns = {'1_Month':'3_Month'}, inplace = True)
df_EQT.rename(columns = {'close_1_Month':'close_3_Month'}, inplace = True)
df_EQT_dates = pd.merge(df_EQT_dates, df_EQT, on='3_Month' ,how='left')
df_EQT_dates['Name'] = 'EQT'

# %%
df_EQT_dates
# Out:
#    Filings       date      1_Day    1_Month    3_Month   close  close_1_Day  \
# 0     10-K 2014-02-20 2014-02-21 2014-03-22 2014-05-21  100.03       100.81
# 1     10-Q 2014-04-24 2014-04-25 2014-05-24 2014-07-23  108.17       105.25
# 2     10-Q 2014-07-24 2014-07-25 2014-08-23 2014-10-22  104.18       100.15
# 3     10-Q 2014-10-23 2014-10-24 2014-11-22 2015-01-21   87.65        88.90
# 4   10-Q/A 2014-12-03 2014-12-04 2015-01-02 2015-03-03   90.06        87.10
# 5     10-K 2015-02-12 2015-02-13 2015-03-14 2015-05-13   80.75        81.18
# 6     10-Q 2015-04-23 2015-04-24 2015-05-23 2015-07-22   87.54        86.59
# 7     10-Q 2015-07-23 2015-07-24 2015-08-22 2015-10-21   76.27        74.28
# 8     10-Q 2015-10-22 2015-10-23 2015-11-21 2016-01-20   68.32        69.44
# 9     10-K 2016-02-11 2016-02-12 2016-03-12 2016-05-11   57.13        59.11
# 10    10-Q 2016-04-28 2016-04-29 2016-05-28 2016-07-27   70.06        70.10
# ...

# %%
df_RSPP_dates = pd.read_excel("data/dates/Document_Filing_Dates.xlsx", sheet_name='RSPP see note')
df_RSPP = pd.read_csv('data/RSPP.csv', encoding="ISO-8859-1", index_col=[0])
df_RSPP.drop(['company', 'open', 'high', 'low','adjusted_close', 'volume', 'dividend_amount', 'split_coefficient' ,'crude_price'], axis=1, inplace=True)
df_RSPP_dates.drop(['RSPP was acquired by CXO so we probably need both'], axis=1, inplace=True)

df_RSPP['date'] = pd.to_datetime(df_RSPP['date'])
df_RSPP = df_RSPP.set_index('date')
df_RSPP = df_RSPP.resample('D').mean()
df_RSPP = df_RSPP.fillna(method='ffill')
df_RSPP = df_RSPP.reset_index(drop=False)
df_RSPP_dates.rename(columns = {'Filing Date':'date'}, inplace = True)
df_RSPP_dates['1_Day'] = df_RSPP_dates['date'] + np.timedelta64(1,'D')
df_RSPP_dates['1_Month'] = df_RSPP_dates['date'] + np.timedelta64(30,'D')
df_RSPP_dates['3_Month'] = df_RSPP_dates['date'] + np.timedelta64(90,'D')
df_RSPP_dates = pd.merge(df_RSPP_dates, df_RSPP, on='date' ,how='left')
df_RSPP.rename(columns = {'date':'1_Day'}, inplace = True)
df_RSPP.rename(columns = {'close':'close_1_Day'}, inplace = True)
df_RSPP_dates = pd.merge(df_RSPP_dates, df_RSPP, on='1_Day' ,how='left')
df_RSPP.rename(columns = {'1_Day':'1_Month'}, inplace = True)
df_RSPP.rename(columns = {'close_1_Day':'close_1_Month'}, inplace = True)
df_RSPP_dates = pd.merge(df_RSPP_dates, df_RSPP, on='1_Month' ,how='left')
df_RSPP.rename(columns = {'1_Month':'3_Month'}, inplace = True)
df_RSPP.rename(columns = {'close_1_Month':'close_3_Month'}, inplace = True)
df_RSPP_dates = pd.merge(df_RSPP_dates, df_RSPP, on='3_Month' ,how='left')
df_RSPP_dates['Name'] = 'RSPP'

df_RSPP_dates.drop(df_RSPP_dates.columns[df_RSPP_dates.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %%
df_RSPP_dates
# Out:
#    Filings       date      1_Day    1_Month    3_Month  close  close_1_Day  \
# 0     10-K 2014-03-31 2014-04-01 2014-04-30 2014-06-29  28.89        29.20
# 1     10-Q 2014-08-14 2014-08-15 2014-09-13 2014-11-12  26.10        27.13
# 2     10-Q 2014-11-10 2014-11-11 2014-12-10 2015-02-08  26.45        27.25
# 3     10-K 2015-03-17 2015-03-18 2015-04-16 2015-06-15  27.07        25.74
# 4     10-Q 2015-05-12 2015-05-13 2015-06-11 2015-08-10  27.65        28.12
# 5     10-Q 2015-08-04 2015-08-05 2015-09-03 2015-11-02  22.76        23.66
# 6     10-Q 2015-11-02 2015-11-03 2015-12-02 2016-01-31  27.23        27.49
# 7     10-K 2016-02-25 2016-02-26 2016-03-26 2016-05-25  22.80        23.02
# 8     10-Q 2016-05-02 2016-05-03 2016-06-01 2016-07-31  31.00        29.62
# 9     10-Q 2016-08-08 2016-08-09 2016-09-07 2016-11-06  39.30        38.19
# 10    10-Q 2016-11-01 2016-11-02 2016-12-01 2017-01-30  36.49        36.81
# ...

# %%
df_ALL_dates = df_FANG_dates.append(df_MDU_dates, ignore_index = True)
df_ALL_dates = df_ALL_dates.append(df_MRO_dates, ignore_index = True)
df_ALL_dates = df_ALL_dates.append(df_LPI_dates, ignore_index = True)
df_ALL_dates = df_ALL_dates.append(df_GPOR_dates, ignore_index = True)
df_ALL_dates = df_ALL_dates.append(df_RRC_dates, ignore_index = True)
df_ALL_dates = df_ALL_dates.append(df_EQT_dates, ignore_index = True)

df_ALL_dates = df_ALL_dates.append(df_RSPP_dates, ignore_index = True)
df_ALL_dates = df_ALL_dates.append(df_PE_dates, ignore_index = True)

# %%
df_ALL_dates
# Out:
#     Filings       date      1_Day    1_Month    3_Month   close  close_1_Day  \
# 0      10-K 2014-02-19 2014-02-20 2014-03-21 2014-05-20   61.04        62.67
# 1      10-Q 2014-05-09 2014-05-10 2014-06-08 2014-08-07   71.24        71.24
# 2    10-Q/A 2014-05-28 2014-05-29 2014-06-27 2014-08-26   71.39        75.02
# 3      10-Q 2014-08-07 2014-08-08 2014-09-06 2014-11-05   76.58        77.45
# 4      10-Q 2014-11-06 2014-11-07 2014-12-06 2015-02-04   65.82        69.49
# 5      10-K 2015-02-20 2015-02-21 2015-03-22 2015-05-21   75.09        75.09
# 6      10-Q 2015-05-07 2015-05-08 2015-06-06 2015-08-05   75.34        77.01
# 7      10-Q 2015-08-10 2015-08-11 2015-09-09 2015-11-08   70.19        70.87
# 8      10-Q 2015-11-06 2015-11-07 2015-12-06 2016-02-04   77.79        77.79
# 9    10-Q/A 2015-11-17 2015-11-18 2015-12-17 2016-02-15   79.61        81.42
# 10     10-K 2016-02-19 2016-02-20 2016-03-20 2016-05-19   72.08        72.08
# ...
